# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt

# File to Load
file_to_load = "./Resources/MoviesOnStreamingPlatforms_updated.csv"

# Read Purchasing File and store into Pandas data frame
csv = pd.read_csv(file_to_load, engine='python')
csv.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
moviecount = (len(csv))
moviecount
# Out:
# 16744

# %%
newdata = csv[(csv['Year'] > 2009) & (csv['Year'] < 2019)]
newdata
# Out:
#        Unnamed: 0     ID                                        Title  Year  \
# 0               0      1                                    Inception  2010
# 2               2      3                       Avengers: Infinity War  2018
# 5               5      6            Spider-Man: Into the Spider-Verse  2018
# 7               7      8                             Django Unchained  2012
# 13             13     14                                         Room  2015
# ...           ...    ...                                          ...   ...
# 16733       16733  16734  Sea of Hope: America's Underwater Treasures  2017
# 16735       16735  16736                    Secrets of the King Cobra  2010
# 16736       16736  16737          Winged Seduction: Birds of Paradise  2012
# 16741       16741  16742                        Sharks of Lost Island  2013
# 16742       16742  16743                           Man Among Cheetahs  2017
#
#        Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0      13+   8.8             87%        1     0            0        0     0
# 2      13+   8.5             84%        1     0            0        0     0
# 5       7+   8.4             97%        1     0            0        0     0
# 7      18+   8.4             87%        1     0            0        0     0
# 13     18+   8.1             93%        1     0            0        0     0
# ...    ...   ...             ...      ...   ...          ...      ...   ...
# 16733  NaN   7.3             NaN        0     0            0        1     0
# 16735  NaN   6.4             NaN        0     0            0        1     0
# 16736  NaN   6.5             NaN        0     0            0        1     0
# 16741  NaN   5.7             NaN        0     0            0        1     0
# 16742  NaN   6.6             NaN        0     0            0        1     0
#
#                                          Directors  \
# 0                                Christopher Nolan
# 2                          Anthony Russo,Joe Russo
# 5      Bob Persichetti,Peter Ramsey,Rodney Rothman
# 7                                Quentin Tarantino
# 13                                Lenny Abrahamson
# ...                                            ...
# 16733                                 Robert Nixon
# 16735                                          NaN
# 16736                                Molly Hermann
# 16741                                 Neil Gelinas
# 16742                         Richard Slater-Jones
#
#                                          Genres  \
# 0              Action,Adventure,Sci-Fi,Thriller
# 2                       Action,Adventure,Sci-Fi
# 5      Animation,Action,Adventure,Family,Sci-Fi
# 7                                 Drama,Western
# 13                               Drama,Thriller
# ...                                         ...
# 16733                               Documentary
# 16735                               Documentary
# 16736                               Documentary
# 16741                               Documentary
# 16742                               Documentary
#
#                                            Country  \
# 0                     United States,United Kingdom
# 2                                    United States
# 5                                    United States
# 7                                    United States
# 13     Ireland,Canada,United Kingdom,United States
# ...                                            ...
# 16733                                United States
# 16735                                        India
# 16736                                United States
# 16741                                United States
# 16742                                United States
#
#                             Language  Runtime
# 0            English,Japanese,French    148.0
# 2                            English    149.0
# 5                    English,Spanish    117.0
# 7      English,German,French,Italian    165.0
# 13                           English    118.0
# ...                              ...      ...
# 16733                        English     48.0
# 16735                        English      NaN
# 16736                        English      NaN
# 16741                        English      NaN
# 16742                        English      NaN
#
# [8928 rows x 17 columns]

# %% [markdown]
# ## Which streaming platform has the most movies?

# %%
total_movies=newdata["Title"].count()
total_movies
# Out:
# 8928

# %%
Netflix = newdata["Netflix"].value_counts()
Netflix[1]
# Out:
# 2440

# %%
Hulu = newdata["Hulu"].value_counts()
Hulu[1]
# Out:
# 590

# %%
PrimeVideo = newdata["Prime Video"].value_counts()
PrimeVideo[1]
# Out:
# 6156

# %%
Disney = newdata["Disney+"].value_counts()
Disney[1]
# Out:
# 135

# %%
number_movies= pd.DataFrame({"Number of Netflix Movies": [Netflix[1]], "Number of Hulu Movies": [Hulu[1]], 
                             "Number of Prime Video Movies":[PrimeVideo[1]], "Number of Disney+ Movies":[Disney[1]]})
number_movies
# Out:
#    Number of Netflix Movies  Number of Hulu Movies  \
# 0                      2440                    590
#
#    Number of Prime Video Movies  Number of Disney+ Movies
# 0                          6156                       135

# %%
number_movies.plot(kind = "bar", figsize = (10,5))

plt.title("Number of Movies on Each Streaming Platform")
plt.xlabel("Streaming Platforms")
plt.ylabel("Number of Movies")

plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Netflix', 'Hulu', 'Prime Video', 'Disney+'
sizes = [2440, 590, 6156, 135]
explode = (0, 0, 0, 0)  

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 

plt.show()

# %% [markdown]
# ## Which streaming platform has the greatest number of popular movies?

# %% [markdown]
# ## Netflix: Rotten Tomatoes

# %%
RTrating = newdata[('Rotten Tomatoes')].sort_values()
RT2 = RTrating.dropna(how = 'any')
RTdf = pd.DataFrame(newdata[['Netflix','Rotten Tomatoes', 'Title']])
RTdf.dropna(inplace=True)
RTdf = RTdf[RTdf.Netflix != 0]
RTdf
# Out:
#       Netflix Rotten Tomatoes                              Title
# 0           1             87%                          Inception
# 2           1             84%             Avengers: Infinity War
# 5           1             97%  Spider-Man: Into the Spider-Verse
# 7           1             87%                   Django Unchained
# 13          1             93%                               Room
# ...       ...             ...                                ...
# 3230        1             60%                            Garbage
# 3332        1             40%                         Mantostaan
# 3365        1             20%               The Price of Success
# 3430        1             40%                             Mantra
# 3440        1             17%                      Coffee with D
#
# [971 rows x 3 columns]

# %%
RTdf.to_csv("Resources/netflix.csv")
netflix = pd.read_csv("Resources/netflix.csv")
netflix["Rotten Tomatoes"] = netflix["Rotten Tomatoes"].str.replace('%', "")
netflix["Rotten Tomatoes"] = pd.to_numeric(netflix["Rotten Tomatoes"])
netflix["Rotten Tomatoes"].dtypes
# Out:
# dtype('int64')

# %%
RTrating = netflix[('Rotten Tomatoes')].sort_values()
RT2 = RTrating.dropna(how = 'any')
RTdf = pd.DataFrame(netflix[['Netflix','Rotten Tomatoes', 'Title']])
RTdf.dropna(inplace=True)
RTdf = RTdf[RTdf.Netflix != 0]
RTdf
# Out:
#      Netflix  Rotten Tomatoes                              Title
# 0          1               87                          Inception
# 1          1               84             Avengers: Infinity War
# 2          1               97  Spider-Man: Into the Spider-Verse
# 3          1               87                   Django Unchained
# 4          1               93                               Room
# ..       ...              ...                                ...
# 966        1               60                            Garbage
# 967        1               40                         Mantostaan
# 968        1               20               The Price of Success
# 969        1               40                             Mantra
# 970        1               17                      Coffee with D
#
# [971 rows x 3 columns]

# %%
# Make bins based on Percentages
bins = [0, 20, 40, 60,80, 100]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
netflix["Rotten Tomatoes Label"] = pd.cut(netflix["Rotten Tomatoes"], bins, labels= percentages, include_lowest=True)

netflix.head()
# Out:
#    Unnamed: 0  Netflix  Rotten Tomatoes                              Title  \
# 0           0        1               87                          Inception
# 1           2        1               84             Avengers: Infinity War
# 2           5        1               97  Spider-Man: Into the Spider-Verse
# 3           7        1               87                   Django Unchained
# 4          13        1               93                               Room
#
#   Rotten Tomatoes Label
# 0               Awesome
# 1               Awesome
# 2               Awesome
# 3               Awesome
# 4               Awesome

# %%
netflixbar = netflix.groupby("Rotten Tomatoes Label")
netflixbar2 = netflixbar["Netflix"].count()

# %%
netflixbar2.plot.bar()
plt.title("Netflix: Rotten Tomatoes Ratings")
plt.xlabel("Rotten Tomatoes Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Hulu: Rotten Tomatoes

# %%
RThulurating = newdata[('Rotten Tomatoes')].sort_values()
RThulu2 = RThulurating.dropna(how = 'any')
RThuludf = pd.DataFrame(newdata[['Hulu','Rotten Tomatoes', 'Title']])
RThuludf.dropna(inplace=True)
RThuludf = RThuludf[RThuludf.Hulu != 0]
RThuludf
# Out:
#       Hulu Rotten Tomatoes                                Title
# 67       1             98%                            Blackfish
# 97       1             99%                 Jiro Dreams of Sushi
# 148      1            100%                           The Square
# 285      1            100%         Hey Arnold! The Jungle Movie
# 340      1             52%                        The Interview
# ...    ...             ...                                  ...
# 4320     1             15%                        Let's Be Evil
# 4327     1             50%  Julian Schnabel: A Private Portrait
# 4338     1             72%            This One's for the Ladies
# 4344     1              4%                 Beneath the Darkness
# 4363     1             69%           The Quest of Alain Ducasse
#
# [410 rows x 3 columns]

# %%
RThuludf.to_csv("Resources/hulu.csv")
hulu = pd.read_csv("Resources/hulu.csv")
hulu["Rotten Tomatoes"] = hulu["Rotten Tomatoes"].str.replace('%', "")
hulu["Rotten Tomatoes"] = pd.to_numeric(hulu["Rotten Tomatoes"])
hulu["Rotten Tomatoes"].dtypes
# Out:
# dtype('int64')

# %%
RThulurating = hulu[('Rotten Tomatoes')].sort_values()
RThulu2 = RThulurating.dropna(how = 'any')
RThuludf = pd.DataFrame(hulu[['Hulu','Rotten Tomatoes', 'Title']])
RThuludf.dropna(inplace=True)
RThuludf = RThuludf[RThuludf.Hulu != 0]
RThuludf
# Out:
#      Hulu  Rotten Tomatoes                                Title
# 0       1               98                            Blackfish
# 1       1               99                 Jiro Dreams of Sushi
# 2       1              100                           The Square
# 3       1              100         Hey Arnold! The Jungle Movie
# 4       1               52                        The Interview
# ..    ...              ...                                  ...
# 405     1               15                        Let's Be Evil
# 406     1               50  Julian Schnabel: A Private Portrait
# 407     1               72            This One's for the Ladies
# 408     1                4                 Beneath the Darkness
# 409     1               69           The Quest of Alain Ducasse
#
# [410 rows x 3 columns]

# %%
# Make bins based on Percentages
bins = [0, 20, 40, 60,80, 100]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
hulu["Rotten Tomatoes Label"] = pd.cut(hulu["Rotten Tomatoes"], bins, labels= percentages, include_lowest=True)
hulu.head()
# Out:
#    Unnamed: 0  Hulu  Rotten Tomatoes                         Title  \
# 0          67     1               98                     Blackfish
# 1          97     1               99          Jiro Dreams of Sushi
# 2         148     1              100                    The Square
# 3         285     1              100  Hey Arnold! The Jungle Movie
# 4         340     1               52                 The Interview
#
#   Rotten Tomatoes Label
# 0               Awesome
# 1               Awesome
# 2               Awesome
# 3               Awesome
# 4                  Good

# %%
hulubar = hulu.groupby("Rotten Tomatoes Label")
hulubar2 = hulubar["Hulu"].count()

# %%
hulubar2.plot.bar()
plt.title("Hulu: Rotten Tomatoes Ratings")
plt.xlabel("Rotten Tomatoes Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Disney+: Rotten Tomatoes

# %%
RTdisneyrating = newdata[('Rotten Tomatoes')].sort_values()
RTdisney2 = RTdisneyrating.dropna(how = 'any')
RTdisneydf = pd.DataFrame(newdata[['Disney+','Rotten Tomatoes', 'Title']])
RTdisneydf.dropna(inplace=True)
RTdisneydf = RTdisneydf[RTdisneydf["Disney+"] != 0]
RTdisneydf
# Out:
#        Disney+ Rotten Tomatoes                           Title
# 95           1             79%                Saving Mr. Banks
# 103          1             95%                             Amy
# 482          1             88%                      White Fang
# 1761         1             20%              The Little Mermaid
# 3580         1             97%                       Free Solo
# ...        ...             ...                             ...
# 16480        1            100%  Marvel Rising: Secret Warriors
# 16481        1             37%                 Mars Needs Moms
# 16482        1             60%    Sharpay's Fabulous Adventure
# 16515        1             36%                            Prom
# 16611        1             40%                     Life-Size 2
#
# [74 rows x 3 columns]

# %%
RTdisneydf.to_csv("Resources/disney.csv")
disney = pd.read_csv("Resources/disney.csv")
disney["Rotten Tomatoes"] = disney["Rotten Tomatoes"].str.replace('%', "")
disney["Rotten Tomatoes"] = pd.to_numeric(disney["Rotten Tomatoes"])
disney["Rotten Tomatoes"].dtypes
# Out:
# dtype('int64')

# %%
RTdisneyrating = disney[('Rotten Tomatoes')].sort_values()
RTdisney2 = RTdisneyrating.dropna(how = 'any')
RTdisneydf = pd.DataFrame(disney[['Disney+','Rotten Tomatoes', 'Title']])
RTdisneydf.dropna(inplace=True)
RTdisneydf = RTdisneydf[RTdisneydf["Disney+"] != 0]
RTdisneydf
# Out:
#     Disney+  Rotten Tomatoes                           Title
# 0         1               79                Saving Mr. Banks
# 1         1               95                             Amy
# 2         1               88                      White Fang
# 3         1               20              The Little Mermaid
# 4         1               97                       Free Solo
# ..      ...              ...                             ...
# 69        1              100  Marvel Rising: Secret Warriors
# 70        1               37                 Mars Needs Moms
# 71        1               60    Sharpay's Fabulous Adventure
# 72        1               36                            Prom
# 73        1               40                     Life-Size 2
#
# [74 rows x 3 columns]

# %%
# Make bins based on Percentages

bins = [0, 20, 40, 60,80, 100]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
disney["Rotten Tomatoes Label"] = pd.cut(disney["Rotten Tomatoes"], bins, labels= percentages, include_lowest=True)

disney.head()
# Out:
#    Unnamed: 0  Disney+  Rotten Tomatoes               Title  \
# 0          95        1               79    Saving Mr. Banks
# 1         103        1               95                 Amy
# 2         482        1               88          White Fang
# 3        1761        1               20  The Little Mermaid
# 4        3580        1               97           Free Solo
#
#   Rotten Tomatoes Label
# 0                 Great
# 1               Awesome
# 2               Awesome
# 3              Terrible
# 4               Awesome

# %%
disneybar = disney.groupby("Rotten Tomatoes Label")
disneybar2 = disneybar["Disney+"].count()

# %%
disneybar2.plot.bar()

plt.title("Disney: Rotten Tomatoes Ratings")
plt.xlabel("Rotten Tomatoes Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Amazon Prime Video: Rotten Tomatoes

# %%
RTamazonrating = newdata[('Rotten Tomatoes')].sort_values()
RTamazon2 = RTamazonrating.dropna(how = 'any')
RTamazondf = pd.DataFrame(newdata[['Prime Video','Rotten Tomatoes', 'Title']])
RTamazondf.dropna(inplace=True)
RTamazondf = RTamazondf[RTamazondf["Prime Video"] != 0]
RTamazondf
# Out:
#        Prime Video Rotten Tomatoes                         Title
# 31               1             92%                         Drive
# 32               1             94%                Train to Busan
# 103              1             95%                           Amy
# 142              1             99%                    Starred Up
# 148              1            100%                    The Square
# ...            ...             ...                           ...
# 15269            1             20%                     Northeast
# 15625            1             50%  You Don't Need Feet to Dance
# 15669            1             13%           The Man On Her Mind
# 15671            1             14%                Double Trouble
# 15733            1             22%                     Freestyle
#
# [1646 rows x 3 columns]

# %%
RTamazondf.to_csv("Resources/amazon.csv")
amazon = pd.read_csv("Resources/amazon.csv")
amazon["Rotten Tomatoes"] = amazon["Rotten Tomatoes"].str.replace('%', "")
amazon["Rotten Tomatoes"] = pd.to_numeric(amazon["Rotten Tomatoes"])
amazon["Rotten Tomatoes"].dtypes
# Out:
# dtype('int64')

# %%
RTamazonrating = amazon[('Rotten Tomatoes')].sort_values()
RTamazon2 = RTamazonrating.dropna(how = 'any')
RTamazondf = pd.DataFrame(amazon[['Prime Video','Rotten Tomatoes', 'Title']])
RTamazondf.dropna(inplace=True)
RTamazondf = RTamazondf[RTamazondf["Prime Video"] != 0]
RTamazondf
# Out:
#       Prime Video  Rotten Tomatoes                         Title
# 0               1               92                         Drive
# 1               1               94                Train to Busan
# 2               1               95                           Amy
# 3               1               99                    Starred Up
# 4               1              100                    The Square
# ...           ...              ...                           ...
# 1641            1               20                     Northeast
# 1642            1               50  You Don't Need Feet to Dance
# 1643            1               13           The Man On Her Mind
# 1644            1               14                Double Trouble
# 1645            1               22                     Freestyle
#
# [1646 rows x 3 columns]

# %%
# Make bins based on Percentages

bins = [0, 20, 40, 60,80, 100]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
amazon["Rotten Tomatoes Label"] = pd.cut(amazon["Rotten Tomatoes"], bins, labels= percentages, include_lowest=True)

amazon.head()
# Out:
#    Unnamed: 0  Prime Video  Rotten Tomatoes           Title  \
# 0          31            1               92           Drive
# 1          32            1               94  Train to Busan
# 2         103            1               95             Amy
# 3         142            1               99      Starred Up
# 4         148            1              100      The Square
#
#   Rotten Tomatoes Label
# 0               Awesome
# 1               Awesome
# 2               Awesome
# 3               Awesome
# 4               Awesome

# %%
amazonbar = amazon.groupby("Rotten Tomatoes Label")
amazonbar2 = amazonbar["Prime Video"].count()

# %%
amazonbar2.plot.bar()

plt.title("Amazon Prime Video: Rotten Tomatoes Ratings")
plt.xlabel("Rotten Tomatoes Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Netflix IMDb rating

# %%
IMDbrating = newdata[('IMDb')].sort_values()
IMDb2 = IMDbrating.dropna(how = 'any')
IMDbdf = pd.DataFrame(newdata[['Netflix','IMDb', 'Title']])
IMDbdf.dropna(inplace=True)
IMDbdf = IMDbdf[IMDbdf.Netflix != 0]
IMDbdf
# Out:
#       Netflix  IMDb                                              Title
# 0           1   8.8                                          Inception
# 2           1   8.5                             Avengers: Infinity War
# 5           1   8.4                  Spider-Man: Into the Spider-Verse
# 7           1   8.4                                   Django Unchained
# 13          1   8.1                                               Room
# ...       ...   ...                                                ...
# 3456        1   4.4                                   Kaviyude Osyathu
# 3457        1   1.4                                            Aerials
# 3459        1   3.1                                   It's Okay, Buddy
# 3460        1   3.7                                  Behind 'The Cove'
# 3461        1   5.8  Edmilson Filho: Notas, Comedy about Relationships
#
# [2361 rows x 3 columns]

# %%
IMDbdf.to_csv("Resources/IMDbdf.csv")
netflix2 = pd.read_csv("Resources/IMDbdf.csv")
netflix2["IMDb"] = pd.to_numeric(netflix2["IMDb"])
netflix2["IMDb"].dtypes
# Out:
# dtype('float64')

# %%
IMDbrating  = IMDbdf[('IMDb')].sort_values()
IMDbnet = IMDbrating.dropna(how = 'any')
IMDbnet = pd.DataFrame(IMDbdf[['Netflix','IMDb', 'Title']])
IMDbnet.dropna(inplace=True)
IMDbnet = IMDbnet[IMDbnet["IMDb"] != 0]
IMDbnet
# Out:
#       Netflix  IMDb                                              Title
# 0           1   8.8                                          Inception
# 2           1   8.5                             Avengers: Infinity War
# 5           1   8.4                  Spider-Man: Into the Spider-Verse
# 7           1   8.4                                   Django Unchained
# 13          1   8.1                                               Room
# ...       ...   ...                                                ...
# 3456        1   4.4                                   Kaviyude Osyathu
# 3457        1   1.4                                            Aerials
# 3459        1   3.1                                   It's Okay, Buddy
# 3460        1   3.7                                  Behind 'The Cove'
# 3461        1   5.8  Edmilson Filho: Notas, Comedy about Relationships
#
# [2361 rows x 3 columns]

# %%
bins = [0, 2, 4, 6,8, 10]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
IMDbdf["IMDb Label"] = pd.cut(IMDbdf["IMDb"], bins, labels= percentages, include_lowest=True)

IMDbdf.head()
# Out:
#     Netflix  IMDb                              Title IMDb Label
# 0         1   8.8                          Inception    Awesome
# 2         1   8.5             Avengers: Infinity War    Awesome
# 5         1   8.4  Spider-Man: Into the Spider-Verse    Awesome
# 7         1   8.4                   Django Unchained    Awesome
# 13        1   8.1                               Room    Awesome

# %%
netflixbarimdb = IMDbdf.groupby("IMDb Label")
netflixbarimdb2 = netflixbarimdb["Netflix"].count()

# %%
netflixbarimdb2.plot.bar()
plt.title("Netflix: IMDb Ratings")
plt.xlabel("IMDb Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Hulu IMDb rating

# %%
IMDbhulurating = newdata[('IMDb')].sort_values()
IMDbhulu2 = IMDbhulurating.dropna(how = 'any')
IMDbhuludf = pd.DataFrame(newdata[['Hulu','IMDb', 'Title']])
IMDbhuludf.dropna(inplace=True)
IMDbhuludf = IMDbhuludf[IMDbhuludf.Hulu != 0]
IMDbhuludf
# Out:
#       Hulu  IMDb                                   Title
# 67       1   8.1                               Blackfish
# 97       1   7.9                    Jiro Dreams of Sushi
# 148      1   8.1                              The Square
# 285      1   7.6            Hey Arnold! The Jungle Movie
# 340      1   6.5                           The Interview
# ...    ...   ...                                     ...
# 4427     1   5.1                                Boomtown
# 4428     1   4.2                    Pixi Saves Christmas
# 4429     1   2.5  Night of the Living Dead: Resurrection
# 4430     1   4.7                       Man-Eating Python
# 4431     1   4.3            Christmas with the Andersons
#
# [582 rows x 3 columns]

# %%
IMDbhuludf.to_csv("Resources/IMDbhuludf.csv")
hulu3 = pd.read_csv("Resources/IMDbhuludf.csv")
hulu3["IMDb"] = pd.to_numeric(hulu3["IMDb"])
hulu3["IMDb"].dtypes
# Out:
# dtype('float64')

# %%
IMDbhulurating  = IMDbhuludf[('IMDb')].sort_values()
IMDbhulu = IMDbhulurating.dropna(how = 'any')
IMDbhulu = pd.DataFrame(IMDbhuludf[['Hulu','IMDb', 'Title']])
IMDbhulu.dropna(inplace=True)
IMDbhulu = IMDbhulu[IMDbhulu["IMDb"] != 0]
IMDbhulu
# Out:
#       Hulu  IMDb                                   Title
# 67       1   8.1                               Blackfish
# 97       1   7.9                    Jiro Dreams of Sushi
# 148      1   8.1                              The Square
# 285      1   7.6            Hey Arnold! The Jungle Movie
# 340      1   6.5                           The Interview
# ...    ...   ...                                     ...
# 4427     1   5.1                                Boomtown
# 4428     1   4.2                    Pixi Saves Christmas
# 4429     1   2.5  Night of the Living Dead: Resurrection
# 4430     1   4.7                       Man-Eating Python
# 4431     1   4.3            Christmas with the Andersons
#
# [581 rows x 3 columns]

# %%
bins = [0, 2, 4, 6,8, 10]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
IMDbhuludf["IMDb Label"] = pd.cut(IMDbhuludf["IMDb"], bins, labels= percentages, include_lowest=True)

IMDbhuludf.head()
# Out:
#      Hulu  IMDb                         Title IMDb Label
# 67      1   8.1                     Blackfish    Awesome
# 97      1   7.9          Jiro Dreams of Sushi      Great
# 148     1   8.1                    The Square    Awesome
# 285     1   7.6  Hey Arnold! The Jungle Movie      Great
# 340     1   6.5                 The Interview      Great

# %%
hulubarimdb = IMDbhuludf.groupby("IMDb Label")
hulubarimdb2 = hulubarimdb["Hulu"].count()

# %%
netflixbarimdb2.plot.bar()

plt.title("Hulu: IMDb Ratings")
plt.xlabel("IMDb Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Disney+ IMDb

# %%
IMDbdisneyrating = newdata[('IMDb')].sort_values()
IMDbdisney2 = IMDbdisneyrating.dropna(how = 'any')
IMDbdisneydf = pd.DataFrame(newdata[['Disney+','IMDb', 'Title']])
IMDbdisneydf.dropna(inplace=True)
IMDbdisneydf = IMDbdisneydf[IMDbdisneydf["Disney+"] != 0]
IMDbdisneydf
# Out:
#        Disney+  IMDb                                        Title
# 95           1   7.5                             Saving Mr. Banks
# 103          1   7.8                                          Amy
# 482          1   6.9                                   White Fang
# 1647         1   7.9                      Diana: In Her Own Words
# 1761         1   4.2                           The Little Mermaid
# ...        ...   ...                                          ...
# 16733        1   7.3  Sea of Hope: America's Underwater Treasures
# 16735        1   6.4                    Secrets of the King Cobra
# 16736        1   6.5          Winged Seduction: Birds of Paradise
# 16741        1   5.7                        Sharks of Lost Island
# 16742        1   6.6                           Man Among Cheetahs
#
# [135 rows x 3 columns]

# %%
IMDbdisneydf.to_csv("Resources/IMDbdisneydf.csv")
disney3 = pd.read_csv("Resources/IMDbdisneydf.csv")
disney3["IMDb"] = pd.to_numeric(disney3["IMDb"])
disney3["IMDb"].dtypes
# Out:
# dtype('float64')

# %%
IMDbdisneyrating  = IMDbdisneydf[('IMDb')].sort_values()
IMDbdisney = IMDbdisneyrating.dropna(how = 'any')
IMDbdisney = pd.DataFrame(IMDbdisneydf[['Disney+','IMDb', 'Title']])
IMDbdisney.dropna(inplace=True)
IMDbdisney = IMDbdisney[IMDbdisney["IMDb"] != 0]
IMDbdisney
# Out:
#        Disney+  IMDb                                        Title
# 95           1   7.5                             Saving Mr. Banks
# 103          1   7.8                                          Amy
# 482          1   6.9                                   White Fang
# 1647         1   7.9                      Diana: In Her Own Words
# 1761         1   4.2                           The Little Mermaid
# ...        ...   ...                                          ...
# 16733        1   7.3  Sea of Hope: America's Underwater Treasures
# 16735        1   6.4                    Secrets of the King Cobra
# 16736        1   6.5          Winged Seduction: Birds of Paradise
# 16741        1   5.7                        Sharks of Lost Island
# 16742        1   6.6                           Man Among Cheetahs
#
# [135 rows x 3 columns]

# %%
bins = [0, 2, 4, 6,8, 10]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
IMDbdisneydf["IMDb Label"] = pd.cut(IMDbdisneydf["IMDb"], bins, labels= percentages, include_lowest=True)

IMDbdisneydf.head()
# Out:
#       Disney+  IMDb                    Title IMDb Label
# 95          1   7.5         Saving Mr. Banks      Great
# 103         1   7.8                      Amy      Great
# 482         1   6.9               White Fang      Great
# 1647        1   7.9  Diana: In Her Own Words      Great
# 1761        1   4.2       The Little Mermaid       Good

# %%
disneybarimdb = IMDbdisneydf.groupby("IMDb Label")
disneybarimdb2 = disneybarimdb["Disney+"].count()

# %%
disneybarimdb2.plot.bar()
plt.title("Disney+: IMDb Ratings")
plt.xlabel("IMDb Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# ## Prime Video IMDB rating

# %%
IMDbprimerating = newdata[('IMDb')].sort_values()
IMDbprime2 = IMDbprimerating.dropna(how = 'any')
IMDbprimedf = pd.DataFrame(newdata[['Prime Video','IMDb', 'Title']])
IMDbprimedf.dropna(inplace=True)
IMDbprimedf = IMDbprimedf[IMDbprimedf["Prime Video"] != 0]
IMDbprimedf
# Out:
#        Prime Video  IMDb                                  Title
# 31               1   7.8                                  Drive
# 32               1   7.5                         Train to Busan
# 103              1   7.8                                    Amy
# 142              1   7.4                             Starred Up
# 148              1   8.1                             The Square
# ...            ...   ...                                    ...
# 15832            1   2.2                   Clash of the Empires
# 15837            1   1.6  Life's a Jungle: Africa's Most Wanted
# 15848            1   3.1                           Blood Soaked
# 15857            1   2.2                       Enemies Among Us
# 15866            1   1.6                  Kingdom of Gladiators
#
# [5821 rows x 3 columns]

# %%
IMDbprimedf.to_csv("Resources/IMDbprimedf.csv")
prime3 = pd.read_csv("Resources/IMDbprimedf.csv")
prime3["IMDb"] = pd.to_numeric(prime3["IMDb"])
prime3["IMDb"].dtypes
# Out:
# dtype('float64')

# %%
IMDbprimerating  = IMDbprimedf[('IMDb')].sort_values()
IMDbprime = IMDbprimerating.dropna(how = 'any')
IMDbprime = pd.DataFrame(IMDbprimedf[['Prime Video','IMDb', 'Title']])
IMDbprime.dropna(inplace=True)
IMDbprime = IMDbprime[IMDbprime["IMDb"] != 0]
IMDbprime
# Out:
#        Prime Video  IMDb                                  Title
# 31               1   7.8                                  Drive
# 32               1   7.5                         Train to Busan
# 103              1   7.8                                    Amy
# 142              1   7.4                             Starred Up
# 148              1   8.1                             The Square
# ...            ...   ...                                    ...
# 15832            1   2.2                   Clash of the Empires
# 15837            1   1.6  Life's a Jungle: Africa's Most Wanted
# 15848            1   3.1                           Blood Soaked
# 15857            1   2.2                       Enemies Among Us
# 15866            1   1.6                  Kingdom of Gladiators
#
# [5819 rows x 3 columns]

# %%
bins = [0, 2, 4, 6,8, 10]
percentages = ["Terrible", "Fair", "Good", "Great", "Awesome"]
IMDbprimedf["IMDb Label"] = pd.cut(IMDbprimedf["IMDb"], bins, labels= percentages, include_lowest=True)

IMDbprimedf.head()
# Out:
#      Prime Video  IMDb           Title IMDb Label
# 31             1   7.8           Drive      Great
# 32             1   7.5  Train to Busan      Great
# 103            1   7.8             Amy      Great
# 142            1   7.4      Starred Up      Great
# 148            1   8.1      The Square    Awesome

# %%
disneybarimdb = IMDbdisneydf.groupby("IMDb Label")
disneybarimdb2 = disneybarimdb["Disney+"].count()

# %%
disneybarimdb2.plot.bar()

plt.title("Prime Video: IMDb Ratings")
plt.xlabel("IMDb Ratings")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')
